# %%
#This one is for Kinesis Streams producer#
#pip install Faker
#pip install boto3

from faker import Faker
import random as rd
import json
import boto3

access_key = "AKIASK5MCXPYN6DPA4JQ"
secret_key = "2gHNFKIL3DTvSTP5HM40jWP9GhQSGtaR42Fuv1tb"
region = "us-east-1"
session = boto3.Session(aws_access_key_id=access_key, aws_secret_access_key=secret_key, region_name=region)

client = session.client('kinesis')
kinesis_stream = "kinesis-stream-1"
sample = Faker()  

def getData(id, name, country, source):
  data = {}
  data["id"] = id
  data["name"] = name
  data["country"] = country
  data["source"] = source
  return data

temp = 0
while temp<50:
  if temp<=25:
    record = json.dumps(getData(str(rd.randint(1, 100)),sample.name(),sample.country(),'local_system'))
    client.put_record(StreamName=kinesis_stream, Data=record, PartitionKey="1")
  else:
    record = json.dumps(getData(str(rd.randint(1, 100)),sample.name(),sample.country(),'other'))
    client.put_record(StreamName=kinesis_stream, Data=record, PartitionKey="1")
  print(record)
  temp = temp+1
# Out:
# {"id": "4", "name": "Megan Hart", "country": "Comoros", "source": "local_system"}
# {"id": "45", "name": "Jamie Jenkins", "country": "Thailand", "source": "local_system"}
# {"id": "62", "name": "Leslie Moore", "country": "Cayman Islands", "source": "local_system"}
# {"id": "13", "name": "Edward Parker", "country": "Norfolk Island", "source": "local_system"}
# {"id": "59", "name": "Ashley Robertson", "country": "Oman", "source": "local_system"}
# {"id": "82", "name": "Austin Bowen", "country": "Saint Helena", "source": "local_system"}
# {"id": "70", "name": "John Wilson", "country": "Montserrat", "source": "local_system"}
# {"id": "62", "name": "Sara Campbell", "country": "Seychelles", "source": "local_system"}
# {"id": "26", "name": "Amy Lee", "country": "Iran", "source": "local_system"}
# {"id": "46", "name": "Kimberly Ramsey", "country": "Mozambique", "source": "local_system"}
# {"id": "35", "name": "Tracy Cunningham", "country": "Maldives", "source": "local_system"}
# {"id": "62", "name": "William Adkins", "country": "Bahrain", "source": "local_system"}
# {"id": "13", "name": "James Walker", "country": "Cyprus", "source": "local_system"}
# {"id": "95", "name": "Lauren Powers", "country": "Wallis and Futuna", "source": "local_system"}
# {"id": "76", "name": "Amy Woods", "country": "Thailand", "source": "local_system"}
# {"id": "81", "name": "Leonard Crane", "country": "French Guiana", "source": "local_system"}
# {"id": "2", "name": "Nicholas Goodwin", "country": "Honduras", "source": "local_system"}
# {"id": "58", "name": "Jason Myers", "country": "Yemen", "source": "local_system"}
# {"id": "73", "name": "Joshua Fox", "country": "Tajikistan", "source": "local_system"}
# {"id": "75", "name": "David Evans", "country": "Namibia", "source": "local_system"}
# {"id": "46", "name": "Brian Hernandez", "country": "Hong Kong", "source": "local_system"}
# {"id": "42", "name": "Kathleen Lee", "country": "Gabon", "source": "local_system"}
# {"id": "56", "name": "Donald King", "country": "Vietnam", "source": "local_system"}
# {"id": "42", "name": "David Brooks", "country": "Russian Federation", "source": "local_system"}
# {"id": "59", "name": "Emily Keller", "country": "Italy", "source": "local_system"}
# {"id": "45", "name": "Michael Ochoa", "country": "Monaco", "source": "local_system"}
# {"id": "74", "name": "Heather Beard", "country": "Seychelles", "source": "other"}
# {"id": "93", "name": "Kathleen Short", "country": "Argentina", "source": "other"}
# {"id": "87", "name": "Steven Burke", "country": "Egypt", "source": "other"}
# {"id": "17", "name": "Mr. Terry Hicks", "country": "Puerto Rico", "source": "other"}
# {"id": "52", "name": "Max Meza", "country": "Guadeloupe", "source": "other"}
# {"id": "61", "name": "Anna Reynolds", "country": "Saint Martin", "source": "other"}
# {"id": "40", "name": "Matthew Farmer", "country": "Jamaica", "source": "other"}
# {"id": "57", "name": "Sandra Hayes", "country": "Cyprus", "source": "other"}
# {"id": "39", "name": "David Hartman DDS", "country": "Guyana", "source": "other"}
# {"id": "38", "name": "Justin Andrade", "country": "Venezuela", "source": "other"}
# {"id": "41", "name": "Joe Bowen", "country": "Sudan", "source": "other"}
# {"id": "1", "name": "Stephanie Kirby", "country": "Hong Kong", "source": "other"}
# {"id": "80", "name": "Phillip Nunez", "country": "Albania", "source": "other"}
# {"id": "63", "name": "William Reynolds", "country": "Turks and Caicos Islands", "source": "other"}
# {"id": "90", "name": "Kristina Miller", "country": "French Polynesia", "source": "other"}
# {"id": "88", "name": "Patricia Smith", "country": "Nauru", "source": "other"}
# {"id": "82", "name": "Lisa Gregory", "country": "Guernsey", "source": "other"}
# {"id": "60", "name": "Brian Martinez", "country": "Saint Vincent and the Grenadines", "source": "other"}
# {"id": "22", "name": "Matthew Lynch", "country": "Martinique", "source": "other"}
# {"id": "15", "name": "Peggy Stewart", "country": "Qatar", "source": "other"}
# {"id": "37", "name": "Andrew Simpson", "country": "French Polynesia", "source": "other"}
# {"id": "55", "name": "Paul Mccarthy", "country": "Costa Rica", "source": "other"}
# {"id": "79", "name": "Alexandria Jacobson", "country": "Algeria", "source": "other"}
# {"id": "26", "name": "Joshua Lawrence", "country": "Saint Kitts and Nevis", "source": "other"}
